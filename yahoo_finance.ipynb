# %%
import yfinance as yf

# Example: COMI (Commercial International Bank)
ticker = "MCRO.CA"

# Download historical data (daily OHLCV)
data = yf.download("MCRO.CA", start="2018-01-01")

print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Close    High     Low    Open  Volume
# Ticker     MCRO.CA MCRO.CA MCRO.CA MCRO.CA MCRO.CA
# Date
# 2024-03-07    3.08    3.22    3.05    3.15  413866
# 2024-03-10    3.15    3.19    3.00    3.08  659493
# 2024-03-11    3.15    3.18    3.08    3.15   67979
# 2024-03-12    2.85    3.18    2.78    3.15  786834
# 2024-03-13    2.87    2.96    2.70    2.85  773258

# %%
print(data.tail())
# Out:
# Price        Close    High     Low    Open     Volume
# Ticker     MCRO.CA MCRO.CA MCRO.CA MCRO.CA    MCRO.CA
# Date
# 2026-04-15    1.15    1.18    1.14    1.16   80831844
# 2026-04-16    1.15    1.20    1.14    1.15  225322750
# 2026-04-19    1.19    1.22    1.14    1.15  260538266
# 2026-04-20    1.22    1.25    1.20    1.19  242386186
# 2026-04-21    1.21    1.25    1.21    1.22  103643285
