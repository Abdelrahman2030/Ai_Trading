# %%
import yfinance as yf

ticker = "ORWE.CA"

# Download historical data (daily OHLCV)
df = yf.download(ticker, start="2018-01-01")

print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open  Volume
# Ticker       ORWE.CA   ORWE.CA   ORWE.CA   ORWE.CA ORWE.CA
# Date
# 2018-01-01  5.323651  5.323651  5.323651  5.323651       0
# 2018-01-02  5.323651  5.323651  5.323651  5.323651       0
# 2018-01-03  5.272307  5.333278  5.224173  5.320442  142612
# 2018-01-04  5.339696  5.419920  5.297979  5.272308  496533
# 2018-01-07  5.339696  5.339696  5.339696  5.339696       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2045 entries, 2018-01-01 to 2026-04-21
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, ORWE.CA)   2045 non-null   float64
#  1   (High, ORWE.CA)    2045 non-null   float64
#  2   (Low, ORWE.CA)     2045 non-null   float64
#  3   (Open, ORWE.CA)    2045 non-null   float64
#  4   (Volume, ORWE.CA)  2045 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 95.9 KB

# %%
df.to_csv("orwe_data.csv")

# %% [markdown]
# # Feature engineering

# %%
#Price based features
df['return_1d'] = df['Close'].pct_change()
df['return_5d'] = df['Close'].pct_change(5)
df['return_10d'] = df['Close'].pct_change(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 #Price based features
# ----> 2 df['return_1d'] = df['Close'].pct_change()
#       3 df['return_5d'] = df['Close'].pct_change(5)
#       4 df['return_10d'] = df['Close'].pct_change(10)
#
# NameError: name 'df' is not defined
